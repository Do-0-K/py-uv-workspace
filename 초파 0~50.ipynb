# %%
#1 화면에 Hello World 문자열 출력
print('Hello World')
# Out:
# Hello World

# %%
#2 화면에 Mary's cosmetics 출력
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
#3 화면에 신씨가 소리질렀다. "도둑이야". 출력
print("신씨가 소리질렀다. \"도둑이야\"")
# Out:
# 신씨가 소리질렀다. "도둑이야"

# %%
#4 화면에 C:\Windows 출력
print("C:\\Windows")
# Out:
# C:\Windows

# %%
#5 \t 와 \n 의 역할을 설명하시오

- \t는 탭, \n은 줄 바꾸기

# %%
#6 출력 예상하기 print("오늘은", "일요일")
# print함수에서 ,로 구분해주면 공백을 추가해서 출력해줍니다
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
#7 다음을 출력하세요
# naver;kakao;sk;samsung

# 만약 sep을 지정 안해주면 자동으로 공백이 들어가집니다.
print("naver", "kakao", "sk","samsung:",sep=';')
# Out:
# naver;kakao;sk;samsung:

# %%
#8 다음을 출력하세요
# naver/kakao/sk/samsung

print("naver", "kakao", "sk", "samsung",sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
#9 다음을 수정하여 줄바꿈 없이 출력하라
print("first");print("second")

print("first",end='');print('second')
# Out:
# first
# second
# firstsecond

# %%
#10 5/3 결과를 출력하라
print(5/3)
# Out:
# 1.6666666666666667

# %%
#11 삼성전자라는 변수로 50000 바인딩
# 삼성전자 주식 10주 보유하고 있을 때 총 평가금액을 출력

삼성전자 = 50000
print(삼성전자 * 10)
# Out:
# 500000

# %%
#12 바인딩하세요

시가총액 = 298000000000000
현재가 = 50000
PER = 15.79

# %%
#13 두 문자열을 합쳐서 출력
s = "hello"
t = "python"

print(s,t)
# Out:
# hello python

# %%
#14 결과 예상
# 곱하기 먼저 수행
print(2+2*3)
# Out:
# 8

# %%
#15 아래 변수의 타입을 판별하라
a = "132"
print(type(a))
# Out:
# <class 'str'>

# %%
#16 문자열 '720'을 정수형으로 변환
num_str = "720"
num_int = int(num_str)
print(num_int,type(num_int))
# Out:
# 720 <class 'int'>

# %%
#17 정수를 문자열로 변환
num = 100
num_str = str(num)
print(num_str,type(num_str))
# Out:
# 100 <class 'str'>

# %%
#18 문자열을 실수로 변환
num_str = "15.79"
num_flo = float(num_str)
print(num_flo,type(num_flo))
# Out:
# 15.79 <class 'float'>

# %%
#19 문자열을 정수로 변환
year = "2020"
year_int = int(year)
print(year_int,type(year_int))

print(year_int-3)
print(year_int-2)
print(year_int-1)
# Out:
# 2020 <class 'int'>
# 2017
# 2018
# 2019

# %%
#20
# 에어컨이 월 48584원에 무이자 36개월의 조건으로 판매
# 총 금액을 계산하고 화면에 출력

month_pay = 48584
month = 36
print(month_pay * month)
# Out:
# 1749024

# %%
#21 letters의 1번과 3번 문자 출력
letters = 'python'
print(letters[0],letters[2])
# Out:
# p t

# %%
#22 뒤에 4자리만 출력
license_plate = "24가 2210"
print(license_plate[-5::])
# Out:
#  2210

# %%
#23 문자열에서 홀만 출력
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %%
#24 거꾸로 뒤집어 출력
string = "PYTHON"
print(string[-1::-1])
# Out:
# NOHTYP

# %%
#25 전화번호에서 - 제거하고 출력
phone_num = "010-1111-2222"
phone_num = phone_num.replace('-',' ')
print(phone_num)
# Out:
# 010 1111 2222

# %%
#26 전화번호에서 - 제거하고 모두 붙혀 출력
phone_num = "010-1111-2222"
phone_num = phone_num.replace('-','')
print(phone_num)
# Out:
# 01011112222

# %%
#27 웹 페이지 주소에서 도메인을 출력
url = "http://sharebook.kr"
url = url.split('.')
print(url[-1])
# Out:
# kr

# %%
#28 실행결과 예상
lang = 'python'
lang[0] = 'P'
print(lang)

- 문자열은 수정 불가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 #28 실행결과 예상
#       2 lang = 'python'
# ----> 3 lang[0] = 'P'
#       4 print(lang)
#
# TypeError: 'str' object does not support item assignment

# %%
#29 문자열에서 소문자 a를 대문자로 변경
string = 'abcdfe2a354a32a'
string = string.replace('a','A')
print(string)
# Out:
# Abcdfe2A354A32A

# %%
#30 실행 결과 예상
string = 'abcd'
string.replace('b','B')
print(string)

#문자열은 변경할 수 없어 그대로 abcd 출력
#다시 할당해주면 변경된 상태로 출력 가능

string = string.replace('b','B')
print(string)
# Out:
# abcd
# aBcd

# %%
#31 실행 결과 예상
a = "3"
b = "4"
print(a+b)

- 34로 출력
- 문자열 +는 연결을 의미
# Out:
# 34

# %%
#32 실행 결과 예상
print("Hi" * 3)

- HiHiHi
- 문자열 *는 반복을 의미
# Out:
# HiHiHi

# %%
#33 화면에 - 80개 출력
print('-' * 80)
# Out:
# --------------------------------------------------------------------------------

# %%
#34 문자열 더하기와 곱하기 사용
# python java python java python java python java

t1 = 'python'
t2 = 'java'

print((t1+' '+t2+' ')*4)
# Out:
# python java python java python java python java

# %%
#35 포멧을 사용하여 출력
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

print("이름: %s 나이: %d" % (name1, age1))
print("이름: %s 나이: %d" % (name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
#36 35번 문제를 format() 사용해서 풀기
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

print("이름: {} 나이: {}".format(name1,age1))
print("이름: {} 나이: {}".format(name2,age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
#37 f_string을 사용해서 35번 문제 출기
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

print(f"이름: {name1} 나이: {age1}")
print(f"이름: {name2} 나이: {age2}")
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
#38 컴마 제거 후 정수로 변환
상장주식수 = "5,969,782,550"
컴마제거 = 상장주식수.replace(',','')
n = int(컴마제거)
print(n,type(n))
# Out:
# 5969782550 <class 'int'>

# %%
#39 다음 문자열에서 '2020/03'만 출력
분기 = "2020/03(E) (IFRS연결)"
print(분기[:7])
# Out:
# 2020/03

# %%
#40 공백제거
data = "   삼성전자   "
data1 = data.strip()
print(data1)
# Out:
# 삼성전자

# %%
#41 다음 문자열을 대문자로 변경
ticker = "btc_krw"
ticker = ticker.upper()
print(ticker)
# Out:
# BTC_KRW

# %%
#42 다음 문자열을 소문자로 변경
ticker = "BTC_KRW"
ticker = ticker.lower()
print(ticker)
# Out:
# btc_krw

# %%
#43 hello에서 Hello로 변경
s = 'hello'
s = s.capitalize()
print(s)
# Out:
# Hello

# %%
#44 파일이 xlsx로 끝나는지 확인
file_name = "보고서.xlsx"
file_name.endswith("xlsx")
# Out:
# True

# %%
#45 xlsx 또는 xls로 끝나는지 확인
file_name = "보고서.xlsx"
file_name.endswith(("xlsx","xls"))
# Out:
# True

# %%
#46 파일 이름이 2020으로 시작하는지 확인
file_name = "2020_보고서.xlsx"
file_name.startswith("2020")
# Out:
# True

# %%
#47 문자열 나누기
a = "hello world"
a.split()
# Out:
# ['hello', 'world']

# %%
#48 btc와 krw로 나누기
ticker = "btc_krw"
ticker.split("_")
# Out:
# ['btc', 'krw']

# %%
#49 연도, 월, 일로 나누기
date = "2020-05-01"
date.split("-")
# Out:
# ['2020', '05', '01']

# %%
#50 문자열 오른쪽 공백 제거
data = "039490      "
data.rstrip()
# Out:
# '039490'
